# %%
import re
import pandas as pd
from typing import Tuple, Optional, Union
from IPython import get_ipython

# %%
"""

READ DATA AND PREPARE ALL

"""

# %%
path = get_ipython().run_line_magic('pwd','')
print(path)

### EDIT MANUALLY
path1 = r"C:\Users\cacr4002\notebooks\Coverage AI\Text-NLP\Data\Raw\niq_products_data.csv"
path2 = r"C:\Users\cacr4002\notebooks\Coverage AI\Text-NLP\Data\Raw\niq_products_asia_europe.csv"

#print(os.path.exists(paths))
# Out:
# C:\Users\cacr4002\notebooks\Coverage AI\Text-NLP

# %%
### EDIT MANUALLY
### RUN ONCE

DF_NIQ1 = pd.read_csv(path1) 
DF_NIQ2 = pd.read_csv(path2, encoding='cp1252')

# %%
# Define cols to filter by
cols1 = ['Product Name','Tamanio','Unidades']
cols2 = ['Product','Tamanio','Unidades']
### FILTER
DF_NIQ1 = DF_NIQ1[cols1]
DF_NIQ2 = DF_NIQ2[cols2]

dfs = []
for df in [DF_NIQ1,DF_NIQ2]:
    df_renamed = df.copy()
    first_col = df.columns[0]
    df_renamed = df_renamed.rename(columns={first_col: 'Product Name'})
    dfs.append(df_renamed)

# Paso 2: Unir todos los DataFrames
DF_NIQ_FINAL = pd.concat(dfs, ignore_index=True)

# %%
DF_NIQ_FINAL.head()
# Out:
#                           Product Name  Tamanio Unidades
# 0        AMERICANO GANCIA 14Â°  12x950    950.0       ml
# 1     AMERICANO GANCIA 14Âº 12x 450 ml    450.0       ml
# 2     AMERICANO GANCIA 14Â°  6 x1250ML   1250.0       ml
# 3           AMARGO OBRERO 19Â°  12x950    950.0       ml
# 4  GANCIA HIBISCUS SPRITZ 25Â° 6X750ML    750.0       ml

# %%
DF_NIQ_FINAL['Product Name'].size
# Out:
# 1901

# %%
DF_NIQ_FINAL['Unidades'].value_counts()
# Out:
# Unidades
# ml       744
# g        548
# G        387
# l         45
# units     36
# kg        36
# oz        28
# P         23
# ML        19
# L         17
# GR         3
# KG         1
# p          1
# Units      1
# Name: count, dtype: int64

# %%
"""

DELETE NULLS AND UNIFY UNITS OF MEASUREMENT

"""
# Out:
# '\n\nDELETE NULLS AND UNIFY UNITS OF MEASUREMENT\n\n'

# %%
DF_NIQ_FINAL = DF_NIQ_FINAL.dropna(subset=['Tamanio'])
DF_NIQ_FINAL = DF_NIQ_FINAL.dropna(subset=['Unidades'])

# %%
DF_NIQ_FINAL['Unidades'] = DF_NIQ_FINAL['Unidades'].str.lower()
DF_NIQ_FINAL['Unidades'] = DF_NIQ_FINAL['Unidades'].str.replace("gr","g")
DF_NIQ_FINAL = DF_NIQ_FINAL[DF_NIQ_FINAL['Unidades'] != 'p']

# %%
DF_NIQ_FINAL['Product Name'].size
# Out:
# 1864

# %%
DF_NIQ_FINAL['Unidades'].value_counts()
# Out:
# Unidades
# g        938
# ml       763
# l         62
# kg        37
# units     36
# oz        28
# Name: count, dtype: int64

# %%
conversion_facts = {
    'kg':1000,
    'l':1000,
    'oz':29.57
}
def convert_units(row):
    unit = row['Unidades']
    value = row['Tamanio']
    if unit in conversion_facts:
        if unit == 'kg':
            new_unit = 'g'
        elif unit == 'l' or unit == 'oz':
            new_unit = 'ml'
        else:
            new_unit = unit
        return pd.Series([value* conversion_facts[unit], new_unit])
    return pd.Series([value,unit])

    
DF_NIQ_FINAL[['Tamaño', 'Unidades']] = DF_NIQ_FINAL.apply(convert_units, axis=1)

# %%
DF_NIQ_FINAL['Unidades'].value_counts()
# Out:
# Unidades
# g        975
# ml       853
# units     36
# Name: count, dtype: int64

# %%
"""

SEND ALL TO LOWER CASE AND DELETE INFORMATION FROM PRODUCT THAT HAS [] OR ()

"""
# Out:
# '\n\nSEND ALL TO LOWER CASE AND DELETE INFORMATION FROM PRODUCT THAT HAS [] OR ()\n\n'

# %%
DF_NIQ_FINAL['Product Name'] = DF_NIQ_FINAL['Product Name'].str.replace(r"[\[\(].*?[\]\)]","",regex=True)

# %%
"""

NLP STARTS

"""
# Out:
# '\n\nNLP STARTS\n\n'

# %%
# -----------------------------
# Configuración y normalización
# -----------------------------

"""
Definir un diccionario de unidades porque no siempre están bien escritas o en el mismo formato. Se exponen las formas literales de hacerlo. 
* Si hay una nueva forma, debe incluirse a mano.
"""

# NOTA: Se esperan unidades en minúscula
ALIAS_TO_CANONICAL = {
    # Volumen directo a ml
    "ml": ("ml", 1),
    "cc": ("ml", 1), "cm3": ("ml", 1), "cm":("ml", 1),
    "cl": ("ml", 10),
    "l": ("ml", 1000), "lt": ("ml", 1000), "lts": ("ml", 1000),
    "litro": ("ml", 1000), "litros": ("ml", 1000),
    # Inglés / variantes
    "milliliter": ("ml", 1), "milliliters": ("ml", 1),
    "millilitre": ("ml", 1), "millilitres": ("ml", 1),
    "mililiter": ("ml", 1), "mililiters": ("ml", 1),  # por si hay typos comunes
    "millilitro": ("ml", 1), "millilitros": ("ml", 1),
    "mililitro": ("ml", 1), "mililitros": ("ml", 1),
    "liter": ("ml", 1000), "liters": ("ml", 1000),
    "litre": ("ml", 1000), "litres": ("ml", 1000),

    # Masa directo a gr
    "g": ("gr", 1), "gr": ("gr", 1), "grs": ("gr", 1),
    "gm": ("gr", 1), "gms": ("gr", 1),
    "gram": ("gr", 1), "grams": ("gr", 1),
    "gramo": ("gr", 1), "gramos": ("gr", 1),
    "kg": ("gr", 1000), "kgs": ("gr", 1000),
    "kilo": ("gr", 1000), "kilos": ("gr", 1000),
    "k": ("gr", 1000),  # p.ej., "3k" => 3000 gr

    # Otras (opcional)
    "oz": ("ml", 29.57),  # aprox. a ml
}

# Lista de tamaños volumétricos típicos (ml) para inferencia neutral (multilenguaje)
"""
Esto es porque muchas veces hay muchos numeros en el nombre del producto que no aportan, entonces se priorizará solo revisar numeros que están en este listado.
* Si hay un tamaño de mucha frecuencia, puede incluirse también.
"""
COMMON_VOLUME_SIZES = {
    187, 200, 237, 250, 270, 275, 300, 310, 312, 320, 330, 340, 350, 355, 375,
    400, 410, 420, 440, 450, 473, 480, 500, 550, 568, 590, 600, 620, 650, 660,
    680, 700, 710, 720, 740, 750, 770, 800, 850, 900, 940, 950, 970, 990, 1000,
    1125, 1180, 1200, 1250, 1500, 1750, 2000, 2250, 2500, 2700, 3000, 3500, 4000, 5000
}

"""
Palabras genéricas de contenedor (multilenguaje) para inferir volumen cuando no hay unidad explícita. Es decir: Lata 700
* Debe ser modificado a mano para nuevos casos
"""
CONTAINER_HINTS = {
    "can", "tin", "lata", "bottle", "botella", "bouteille", "flasche", "bottiglia",
    "jar", "frasco", "pouch", "sachet", "pack", "box", "caja", "estuche", "carton",
    "display", "bundle", "tray", "keg", "brick", "tetra", "tetrapak", "tetra-pack",
    "tube", "tubo", "ampoule", "ampolla", "vial", "bag", "bolsa"
}

def _canon_from_alias(unit_text: str):
    u = unit_text.strip().lower().replace(' ', '')
    u = u.rstrip('.')
    return ALIAS_TO_CANONICAL.get(u, None)

def _num_to_str(val: Union[int, float]) -> str:
    """Render numérico estable: enteros sin .0, decimales sin ceros de cola."""
    if isinstance(val, int):
        return str(val)
    try:
        f = float(val)
        if abs(f - round(f)) < 1e-6:
            return str(int(round(f)))
        s = f"{f:.6f}".rstrip('0').rstrip('.')
        return s
    except Exception:
        return str(val)

def _to_canonical(num_str: str, unit_str: str) -> Tuple[Union[int, float], str]:
    """Convierte número+unidad a (valor, unidad_canónica) con conversiones (kg->gr, l->ml, etc.)."""
    num = float(num_str.replace(',', '.'))
    m = _canon_from_alias(unit_str)
    if not m:
        return num, "XXX"
    canonical_unit, factor = m
    val = num * factor
    if abs(val - round(val)) < 1e-6:
        val = int(round(val))
    return val, canonical_unit

def _has_container_hint(text_lower: str) -> bool:
    """True si hay palabras de envase/packaging."""
    words = set(re.findall(r'[a-zA-Záéíóúñüäöëïç\-]+', text_lower))
    words = {w.lower() for w in words}
    return len(words.intersection(CONTAINER_HINTS)) > 0

def _is_common_volume(n_str: str) -> bool:
    """True si hay un tamaño muy frecuente"""
    try:
        f = float(n_str.replace(',', '.'))
    except Exception:
        return False
    # Para enteros, revisar en lista
    if abs(f - round(f)) < 1e-6:
        return int(round(f)) in COMMON_VOLUME_SIZES
    return False

def _looks_like_volume(n_str: str) -> bool:
    """Heurística amplia: ¿parece volumen en ml? Acepta decimales."""
    try:
        # Formato estandar de cómo escribir un decimal
        f = float(n_str.replace(',', '.')) 
    except Exception:
        return False
    # Enteros típicos o múltiplos de 50/100 dentro de rango
    if abs(f - round(f)) < 1e-6:
        ni = int(round(f))
        if ni in COMMON_VOLUME_SIZES:
            return True
        return 180 <= ni <= 5000 and (ni % 100 == 0 or ni % 50 == 0)
    # Decimales plausibles para volúmenes pequeños/medianos
    return 5.0 <= f <= 5000.0

def _is_plausible_packcount(n_str: str) -> bool:
    """Conteos de pack típicos. Se puede ajustar manual el rango pero entre mas alto, mayor probabilidad de errores"""
    try:
        n = int(float(n_str.replace(',', '.')))
    except Exception:
        return False
    return 2 <= n <= 72  # packs habituales (puedes subir a 144 si tu dominio lo requiere)

# -----------------------------
# Regex
# -----------------------------

""" ESTRATEGIA
Primero intentamos encontrar número + unidad (junto o separado).
Si no, probamos pack A x B o A / B (con o sin unidad).
Si hay unidad → usar ese número como tamaño.
Si no hay → priorizar si uno está en COMMON_VOLUME_SIZES (p. ej., 950).
Si no, buscamos patrones de conteo de unidades (6u/12, 24/Caja, ESTUCHES 24).
Si nada de lo anterior, capturamos un número suelto y decidimos si parece volumen (ml) o dejarlo como XXX.
"""

# UNIT_RE generado dinámicamente de alias (ordenado por longitud desc para evitar "l" dentro de "liter")
_UNIT_ALIASES = sorted(ALIAS_TO_CANONICAL.keys(), key=len, reverse=True) # Ordernar llaves de ALIAS_TO_CANONICAL
UNIT_RE = r'(?:' + '|'.join(re.escape(u) for u in _UNIT_ALIASES) + r')' # Definición de las unidades de un producto
# Números: enteros o decimales con . o ,
NUM_RE = r'(\d+(?:[.,]\d+)?)'
NUM_RE_NOGRP = r'\d+(?:[.,]\d+)?'
# Al terminar unidad, permitir fin, no-letra, o seguidor de pack (x, ×, /)
UNIT_FOLLOW = r'(?=$|[^a-zA-Z]|[xX×/])'

# 1) "número + unidad" (separado o pegado), soporta '900gx18u', '800mlx14'
PAT_NUM_UNIT_SEP = re.compile(rf'{NUM_RE}\s*({UNIT_RE}){UNIT_FOLLOW}', re.I)
PAT_NUM_UNIT_FUSED = re.compile(rf'{NUM_RE}({UNIT_RE}){UNIT_FOLLOW}', re.I)

# 2) "pack" tipo "12x 450 ml" o "12/950" o "6/32.9" (acepta ×)
PAT_PACK = re.compile(rf'(\d+)\s*[*xX×/]\s*({NUM_RE_NOGRP})(?:\s*({UNIT_RE}){UNIT_FOLLOW})?', re.I)

# 3) "unidades" (multilenguaje)
UNITS_TOK = r'(?:u|un|ud|uds|und\.?|und|unid(?:ad(?:es)?)?|units?|pcs?|pz|pieza(?:s)?)' #Definir formas de encontrar las unidades. Cambiar a mano si es necesario.
# Aqui se definen los casos "12un/24u" o "6u/12"
PAT_UNITS_BOTH = re.compile(rf'(\d+)\s*{UNITS_TOK}\s*/\s*(\d+)\s*{UNITS_TOK}\b', re.I)
PAT_UNITS_FIRST = re.compile(rf'(\d+)\s*{UNITS_TOK}\s*/\s*(\d+)\b', re.I)
# Para cosas como "24/Caja" o "12/box".
PAT_SLASH_CAJA = re.compile(r'(\d+)\s*/\s*(?:caja|cj|c\/j|box|case)\b', re.I)
PAT_WORD_NUM = re.compile(r'(?:estuche(?:s)?|pack|paquete(?:s)?|caja(?:s)?|box(?:es)?|blister(?:s)?|display(?:s)?|case(?:s)?)\D*(\d+)\b', re.I) # Editar si cambia.

# 4) Números sueltos (incluye decimales)
PAT_ANY_NUM = re.compile(rf'\b{NUM_RE_NOGRP}\b')

# %%
def extract_size_unit(product_name: str) -> Tuple[Optional[str], Optional[str]]:
    """
    Regresa (size, unit) donde:
      - unit in {'ml', 'gr', 'units', 'XXX'}
      - size es string (permite '12/24' y decimales como '32.9')
    Reglas clave:
      * Prioriza coincidencias explícitas "número+unidad" (soporta palabras de unidad).
      * En paquetes A/B o AxB sin unidad, prioriza el lado que está en COMMON_VOLUME_SIZES.
      * Si ninguno está en la lista, elige el lado que "parece volumen" y el otro parece conteo de pack.
      * Evita inventar: si no hay señales, devuelve 'XXX'.
    """
    if not product_name or not isinstance(product_name, str):
        return None, None

    s = product_name.strip()
    s_clean = s.lower()
    # Normalizaciones de encoding y variantes
    s_clean = (s_clean
               .replace('c.c.', 'cc')
               .replace('c.c', 'cc')
               .replace('Â°', '°')  # correcciones comunes de encoding
               .replace('â°', '°'))

    # 1) "número + unidad" (prioritario) — soporta decimales y unidad pegada seguida de x/ /
    m = PAT_NUM_UNIT_SEP.search(s_clean) or PAT_NUM_UNIT_FUSED.search(s_clean)
    if m:
        num, unit = m.group(1), m.group(2)
        val, canonical = _to_canonical(num, unit)
        return (_num_to_str(val), canonical)

    # 2) Paquetes "A/B" o "AxB"
    mp = PAT_PACK.search(s_clean)
    if mp:
        left, right, unit = mp.groups()
        if unit:
            # Caso "12x 450 ml"
            val, canonical = _to_canonical(right, unit)
            return (_num_to_str(val), canonical)
        else:
            # Sin unidad explícita: priorizar COMMON_VOLUME_SIZES
            left_common = _is_common_volume(left)
            right_common = _is_common_volume(right)
            if right_common and not left_common:
                return (_num_to_str(float(right.replace(',', '.'))), 'ml')
            if left_common and not right_common:
                return (_num_to_str(float(left.replace(',', '.'))), 'ml')
            if left_common and right_common:
                # Heurística: usualmente el tamaño va a la derecha (12/750 => 750 ml)
                return (_num_to_str(float(right.replace(',', '.'))), 'ml')

            # Si ninguno está en la lista, usar heurística volumen vs. pack
            left_vol = _looks_like_volume(left)
            right_vol = _looks_like_volume(right)
            left_pack = _is_plausible_packcount(left)
            right_pack = _is_plausible_packcount(right)

            # Preferir el que parezca volumen y el otro conteo de pack
            if right_vol and left_pack and not left_vol:
                return (_num_to_str(float(right.replace(',', '.'))), 'ml')
            if left_vol and right_pack and not right_vol:
                return (_num_to_str(float(left.replace(',', '.'))), 'ml')

            # Como señal adicional, si hay contenedor + uno parece volumen, tomarlo
            if _has_container_hint(s_clean):
                if right_vol:
                    return (_num_to_str(float(right.replace(',', '.'))), 'ml')
                if left_vol:
                    return (_num_to_str(float(left.replace(',', '.'))), 'ml')
            # Sin inferencias sólidas -> continuar

    # 3) Conteos de unidades (cuando no hay volumen/masa explícito)
    mu_both = PAT_UNITS_BOTH.search(s_clean)
    if mu_both:
        n1, n2 = mu_both.group(1), mu_both.group(2)
        return (f"{int(n1)}", "units")

    mu_first = PAT_UNITS_FIRST.search(s_clean)
    if mu_first:
        n1 = mu_first.group(1)
        return (str(int(n1)), "units")

    mcj = PAT_SLASH_CAJA.search(s_clean)
    if mcj:
        return (str(int(mcj.group(1))), "units")

    mpw = PAT_WORD_NUM.search(s_clean)
    if mpw:
        return (str(int(mpw.group(1))), "units")

    # 4) Números sueltos: inferir ml sólo si hay contenedor o tamaño típico/plausible
    anyn = PAT_ANY_NUM.search(s_clean)
    if anyn:
        raw = anyn.group(0)
        if _is_common_volume(raw) or (_has_container_hint(s_clean) and _looks_like_volume(raw)):
            return (_num_to_str(float(raw.replace(',', '.'))), 'ml')
        # Fallback seguro: no inventar unidad
        return (_num_to_str(float(raw.replace(',', '.'))), "XXX")

    return None, None

# %%
"""

Definir funcion para probar el modelo

"""
# Out:
# '\n\nDefinir funcion para probar el modelo\n\n'

# %%
def _normalize_number_like(s: Optional[str]) -> Optional[str]:
    """Normaliza strings numéricos para comparación: maneja ',' como '.', recorta ceros."""
    if s is None:
        return None
    st = str(s).strip().lower().replace(',', '.')
    try:
        f = float(st)
        if abs(f - round(f)) < 1e-9:
            return str(int(round(f)))
        return f"{f:.6f}".rstrip('0').rstrip('.')
    except Exception:
        return st

def normalize_expected_value(v) -> Optional[str]:
    return _normalize_number_like(v)

def normalize_expected_unit(u) -> Optional[str]:
    if u is None:
        return None
    u = str(u).strip().lower()
    m = _canon_from_alias(u)
    if m:
        can, _ = m
        return can
    if u in {"unit", "units", "un", "u", "ud", "uds", "und", "und.", "unid", "unids", "unidades", "pcs", "pz", "pieza", "piezas"}:
        return "units"
    if u == "xxx":
        return "xxx"
    return u

def evaluate_extraction(df: pd.DataFrame,
                        product_col: str = "Product Name",
                        size_col: str = "Tamaño",
                        unit_col: str = "Unidades") -> pd.DataFrame:
    """
    Aplica extractor y calcula métricas:
      - accuracy size
      - accuracy unit
      - accuracy ambas
    Devuelve un DataFrame con predicciones y flags de acierto, y hace un resumen por print.
    """
    df = df.copy()
    preds = df[product_col].apply(extract_size_unit)
    df["pred_size"] = preds.apply(lambda x: x[0])
    df["pred_unit"] = preds.apply(lambda x: x[1])

    df["_size_true"] = df[size_col].apply(normalize_expected_value)
    df["_unit_true"] = df[unit_col].apply(normalize_expected_unit)
    df["_size_pred"] = df["pred_size"].apply(normalize_expected_value)
    df["_unit_pred"] = df["pred_unit"].apply(normalize_expected_unit)

    df["size_ok"] = df["_size_pred"] == df["_size_true"]
    df["unit_ok"] = df["_unit_pred"] == df["_unit_true"]
    df["both_ok"] = df["size_ok"] & df["unit_ok"]

    size_acc = df["size_ok"].mean()
    unit_acc = df["unit_ok"].mean()
    both_acc = df["both_ok"].mean()

    print("=== Métricas de extracción ===")
    print(f"Accuracy size: {size_acc:.3f}")
    print(f"Accuracy unit: {unit_acc:.3f}")
    print(f"Accuracy ambos: {both_acc:.3f}")

    unit_summary = (df
        .groupby("_unit_true", dropna=False)
        .agg(
            n=("Product Name", "count"),
            size_acc=("size_ok", "mean"),
            unit_acc=("unit_ok", "mean"),
            both_acc=("both_ok", "mean")
        )
        .sort_values("n", ascending=False)
    )
    print("\n=== Resumen por unidad esperada ===")
    print(unit_summary.to_string())

    return df[[
        product_col, size_col, unit_col, "pred_size", "pred_unit",
        "size_ok", "unit_ok", "both_ok"
    ]]

# %%
results = evaluate_extraction(DF_NIQ_FINAL)
print("\n=== Predicciones detalle ===")
print(results.to_string(index=False))
# Out:
# === Métricas de extracción ===
# Accuracy size: 0.984
# Accuracy unit: 0.983
# Accuracy ambos: 0.981
#
# === Resumen por unidad esperada ===
#               n  size_acc  unit_acc  both_acc
# _unit_true
# gr          975  0.991795  0.989744  0.988718
# ml          853  0.989449  0.988277  0.987104
# units        36  0.666667  0.694444  0.638889
#
# === Predicciones detalle ===
#                                     Product Name    Tamaño Unidades pred_size pred_unit  size_ok  unit_ok  both_ok
#                    AMERICANO GANCIA 14Â°  12x950   950.000       ml       950        ml     True     True     True
#                 AMERICANO GANCIA 14Âº 12x 450 ml   450.000       ml       450        ml     True     True     True
#                 AMERICANO GANCIA 14Â°  6 x1250ML  1250.000       ml      1250        ml     True     True     True
#                       AMARGO OBRERO 19Â°  12x950   950.000       ml       950        ml     True     True     True
#              GANCIA HIBISCUS SPRITZ 25Â° 6X750ML   750.000       ml       750        ml     True     True     True
#            H5663600 - ELV ACO CAIDA RESIST 400ml   400.000       ml       400        ml     True     True     True
#             H5663700 - ELV SH CAIDA RESIST 400ml   400.000       ml       400        ml     True     True     True
#              H5664400 - ELV ARCIL EXTR ACO 400ml   400.000       ml       400        ml     True     True     True
#               H5664500 - ELV ARCIL EXTR SH 400ml   400.000       ml       400        ml     True     True     True
#               H5667500 - ELV ARCIL EXTR SH 200ml   200.000       ml       200        ml     True     True     True
#              H5667600 - ELV ARCIL EXTR ACO 200ml   200.000       ml       200        ml     True     True     True
#      H5680900 - ELVIVE CV PURPLE SH 200ml Arg CM   200.000       ml       200        ml     True     True     True
#    H5681200 - ELVIVE COLOR VIVE ACO 400ml Arg CM   400.000       ml       400        ml     True     True     True
#    H5681300 - ELVIVE COLOR VIVE ACO 200ml Arg CM   200.000       ml       200        ml     True     True     True
#     H5681500 - ELVIVE COLOR VIVE SH 400ml Arg CM   400.000       ml       400        ml     True     True     True
#     H5681600 - ELVIVE COLOR VIVE SH 200ml Arg CM   200.000       ml       200        ml     True     True     True
#     H5681700 - ELVIVE CV PURPLE ACO 200ml Arg CM   200.000       ml       200        ml     True     True     True
#    H5727200 - ELVIVE COLOR VIVE ACO 400ml Arg CM   400.000       ml       400        ml     True     True     True
#    H5727300 - ELVIVE COLOR VIVE ACO 750ml Arg CM   750.000       ml       750        ml     True     True     True
#     H5727400 - ELVIVE COLOR VIVE SH 750ml Arg CM   750.000       ml       750        ml     True     True     True
#           H5727700 - ELV ACO COLORVIVE 200ML ARG   200.000       ml       200        ml     True     True     True
#            H5727900 - ELV SH COLORVIVE 400ML ARG   400.000       ml       400        ml     True     True     True
#           H5728700 - ELV SH COLOR VIVE 200ML ARG   200.000       ml       200        ml     True     True     True
#       H5551100 - ELVIVE DREAM LONG LISS SH 200ml   200.000       ml       200        ml     True     True     True
#       H5551200 - ELVIVE DREAM LONG LISS SH 400ml   400.000       ml       400        ml     True     True     True
#      H5551400 - ELVIVE DREAM LONG LISS ACO 200ml   200.000       ml       200        ml     True     True     True
#      H5551500 - ELVIVE DREAM LONG LISS ACO 400ml   400.000       ml       400        ml     True     True     True
#      H5551600 - ELVIVE DREAM LONG LISS ACO 750ml   750.000       ml       750        ml     True     True     True
#      H5559901 - ELVIVE DREAM LONG LISS CPP 250ml   250.000       ml       250        ml     True     True     True
#           H5662100 - ELV DREAM LENGTH COND 750ml   750.000       ml       750        ml     True     True     True
#           H5662200 - ELV DREAM LENGTH COND 400ml   400.000       ml       400        ml     True     True     True
#             H5662300 - ELV DREAM LENGTH SH 750ml   750.000       ml       750        ml     True     True     True
#             H5662400 - ELV DREAM LENGTH SH 400ml   400.000       ml       400        ml     True     True     True
#             H5667000 - ELV DREAM LENGTH SH 200ml   200.000       ml       200        ml     True     True     True
#           H5667100 - ELV DREAM LENGTH COND 200ml   200.000       ml       200        ml     True     True     True
#            H5668800 - ELV DREAM LENGTH CPP 250ml   250.000       ml       250        ml     True     True     True
#   H5799700 - ElsDr.Length Sleek SH400ml ARG 2025   400.000       ml       400        ml     True     True     True
#   H5799800 - ElsDr.Length CondSleek400ml ARG2025   400.000       ml       400        ml     True     True     True
#   H5799900 - ElsDr.Length CondSleek750ml ARG2025   750.000       ml       750        ml     True     True     True
#   H5800000 - ElsDr.Length CondSleek200ml ARG2025   200.000       ml       200        ml     True     True     True
#   H5800100 - ElsDr.Length Sleek SH750ml ARG 2025   750.000       ml       750        ml     True     True     True
#   H5800200 - ElsDr.Length Sleek SH200ml ARG 2025   200.000       ml       200        ml     True     True     True
#   H5800300 - Dr.Leng Sleek Mask Jar300g ARG 2025   300.000        g       300        gr     True     True     True
#        H5803800 - Dr.Leng SleekCPP 250ML ARG2025   250.000       ml       250        ml     True     True     True
#                H5664000 - ELV OLEO COCO SH 750ml   750.000       ml       750        ml     True     True     True
#               H5664100 - ELV OLEO COCO ACO 400ml   400.000       ml       400        ml     True     True     True
#                H5664600 - ELV OLEO COCO SH 400ml   400.000       ml       400        ml     True     True     True
#        H5664700 - ELV O.EXTRAORD CURLS ACO 400ml   400.000       ml       400        ml     True     True     True
#         H5664900 - ELV O.EXTRAORD CURLS SH 400ml   400.000       ml       400        ml     True     True     True
#     H5665700 - ELV O.EXTRAORD NUTR UNIV CD 400ml   400.000       ml       400        ml     True     True     True
#               H5666800 - ELV OLEO COCO ACO 200ml   200.000       ml       200        ml     True     True     True
#        H5667700 - ELV O.EXTRAORD CURLS ACO 200ml   200.000       ml       200        ml     True     True     True
#         H5667800 - ELV O.EXTRAORD CURLS SH 200ml   200.000       ml       200        ml     True     True     True
#     H5668200 - ELV O.EXTRAORD NUTR UNIV CD 200ml   200.000       ml       200        ml     True     True     True
#                H5668700 - ELV OLEO COCO SH 200ml   200.000       ml       200        ml     True     True     True
#        H5685900 - ELV O.EXTRAORD CURLS CPP 250ml   250.000       ml       250        ml     True     True     True
#        H5686000 - ELVIVE OLEO EXT COCO CPP 250ml   250.000       ml       250        ml     True     True     True
#                H5686100 - ELV OLEO COCO CTT 300g   300.000        g       300        gr     True     True     True
#    H5687900 - ELV OLEO NUTR UNIV SH 400ml ARG CM   400.000       ml       400        ml     True     True     True
#    H5688000 - ELV OLEO NUTR UNIV SH 200ml ARG CM   200.000       ml       200        ml     True     True     True
#            H5716900 - ELV OLEO EXT. 100ML ARG CM   100.000       ml       100        ml     True     True     True
#            H5716901 - ELV OLEO EXT. 100ML ARG CM   100.000       ml       100        ml     True     True     True
#   H5744600 - ELV Oleo Extraordinario Rizo SH 200   200.000       ml       200        ml     True     True     True
#   H5744700 - ELV Oleo Extraordinario Rizo SH 400   400.000       ml       400        ml     True     True     True
#   H5744800 - ELV Oleo Extraordinario Rizo ACO200   200.000       ml      None      None    False    False    False
#   H5744900 - ELV Oleo Extraordinario Rizo ACO400   400.000       ml      None      None    False    False    False
#             H1499701 - ELV FIBRALOGY ACO 400ML .   400.000       ml       400        ml     True     True     True
#              H5746200 - ELV Glyco Gloss SH 400ml   400.000       ml       400        ml     True     True     True
#             H5746400 - ELV Glyco Gloss CPP 250ml   250.000       ml       250        ml     True     True     True
#           H5746500 - ELV Glyco Gloss Serum 100ml   100.000       ml       100        ml     True     True     True
#             H5748000 - ELV Glyco Gloss ACO 200ml   200.000       ml       200        ml     True     True     True
#             H5748100 - ELV Glyco Gloss ACO 400ml   400.000       ml       400        ml     True     True     True
#              H5768600 - ELV Glyco Gloss SH 200ml   200.000       ml       200        ml     True     True     True
#        H5593100 - ELV HIDRA HIALURONICO SH 200ML   200.000       ml       200        ml     True     True     True
#        H5593200 - ELV HIDRA HIALURONICO SH 400ML   400.000       ml       400        ml     True     True     True
#        H5593300 - ELV HIDRA HIALURONICO SH 750ML   750.000       ml       750        ml     True     True     True
#       H5593400 - ELV HIDRA HIALURONICO ACO 200ML   200.000       ml       200        ml     True     True     True
#       H5593700 - ELV HIDRA HIALURONICO CPP 250ML   250.000       ml       250        ml     True     True     True
#       H5618700 - ELV HIDRA HIALURONICO CTT 300ML   300.000       ml       300        ml     True     True     True
#        H5700700 - ELVIVE HA PURE SH 750ml ARG CM   750.000       ml       750        ml     True     True     True
#   H5702200 - ELVIVE HA PURE SHAMPOO 200ml ARG CM   200.000       ml       200        ml     True     True     True
#   H5702201 - ELVIVE HA PURE SHAMPOO 200ml ARG CM   200.000       ml       200        ml     True     True     True
#       H5702300 - ELVIVE HA PURE ACO 200ml ARG CM   200.000       ml       200        ml     True     True     True
#        H5702400 - ELVIVE HA PURE CTT 300g ARG CM   300.000        g       300        gr     True     True     True
#   H5702500 - ELVIVE HA PURE SHAMPOO 400ML ARG CM   400.000       ml       400        ml     True     True     True
#   H5702501 - ELVIVE HA PURE SHAMPOO 400ML ARG CM   400.000       ml       400        ml     True     True     True
#       H5702900 - ELVIVE HA PURE ACO 400ML ARG CM   400.000       ml       400        ml     True     True     True
#       H5703500 - ELVIVE HA PURE ACO 750ml ARG CM   750.000       ml       750        ml     True     True     True
#        H5724300 - HIDRA HIALURONICO SH 200ML ARG   200.000       ml       200        ml     True     True     True
#        H5724400 - HIDRA HIALURONICO SH 400ML ARG   400.000       ml       400        ml     True     True     True
#        H5724500 - HIDRA HIALURONICO SH 750ML ARG   750.000       ml       750        ml     True     True     True
#       H5724600 - HIDRA HIALURONICO ACO 200ML ARG   200.000       ml       200        ml     True     True     True
#       H5724700 - HIDRA HIALURONICO ACO 400ML ARG   400.000       ml       400        ml     True     True     True
#       H5725000 - HIDRA HIALURONICO CTT 300ML ARG   300.000       ml       300        ml     True     True     True
#             H5665200 - ELV KERA-LISO MK SH 400ml   400.000       ml       400        ml     True     True     True
#     H5665300 - ELV KERA-LISO BRIL Y SED SH 750ml   750.000       ml       750        ml     True     True     True
#            H5665400 - ELV KERA-LISO MK ACO 400ml   400.000       ml       400        ml     True     True     True
#     H5665500 - ELV KERA-LISO BRIL Y SED SH 400ml   400.000       ml       400        ml     True     True     True
#     H5665900 - ELV KERALISO BRIL Y SED ACO 400ml   400.000       ml       400        ml     True     True     True
#           H5667200 - ELV CT KERA-LISO 230Â° 300g   300.000        g       300        gr     True     True     True
#            H5667900 - ELV KERA-LISO MK ACO 200ml   200.000       ml       200        ml     True     True     True
#     H5668000 - ELV KERA-LISO BRIL Y SED SH 200ml   200.000       ml       200        ml     True     True     True
#     H5668100 - ELV KERALISO BRIL Y SED ACO 200ml   200.000       ml       200        ml     True     True     True
#      H5668600 - ELV CT KERA-LISO MOVIMIENTO 300g   300.000        g       300        gr     True     True     True
#             H5673400 - ELV KERA-LISO MK SH 200ml   200.000       ml       200        ml     True     True     True
#         H5726600 - ELV KERA-LISO MK SH 200ML ARG   200.000       ml       200        ml     True     True     True
#         H5726700 - ELV KERA-LISO MK SH 400ML ARG   400.000       ml       400        ml     True     True     True
#        H5726800 - ELV KERA-LISO MK ACO 200ML ARG   200.000       ml       200        ml     True     True     True
#        H5726900 - ELV KERA-LISO MK ACO 400ML ARG   400.000       ml       400        ml     True     True     True
#           H0665606 - ELV ACO REP TOTAL 5 200ML .   200.000       ml       200        ml     True     True     True
#              H5661400 - ELV RT EXTREME ACO 400ml   400.000       ml       400        ml     True     True     True
#               H5661500 - ELV RT EXTREME SH 400ml   400.000       ml       400        ml     True     True     True
#             H5661600 - ELV ACO RT5 750ml KERATIN   750.000       ml       750        ml     True     True     True
#    H5661800 - ELVIVE RT5+  SH 2EN1 400ml KERATIN   400.000       ml       400        ml     True     True     True
#     H5661900 - ELV ACO REP TOTAL 5 400ml KERATIN   400.000       ml       400        ml     True     True     True
#             H5662000 - ELV SH RT5+ 400ml KERATIN   400.000       ml       400        ml     True     True     True
#   H5666000 - ELVIVE REP TOT 5+ CTT 300ml KERATIN   300.000       ml       300        ml     True     True     True
#               H5666200 - ELV RT EXTREME CTT 300g   300.000        g       300        gr     True     True     True
#     H5666700 - ELV ACO REP TOTAL 5 200ml KERATIN   200.000       ml       200        ml     True     True     True
#             H5666900 - ELV SH RT5+ 200ml KERATIN   200.000       ml       200        ml     True     True     True
#               H5667300 - ELV RT EXTREME SH 200ml   200.000       ml       200        ml     True     True     True
#              H5673300 - ELV RT EXTREME ACO 200ml   200.000       ml       200        ml     True     True     True
#           H5725100 - ELV RT EXTREME SH 200ML ARG   200.000       ml       200        ml     True     True     True
#           H5725200 - ELV RT EXTREME SH 400ML ARG   400.000       ml       400        ml     True     True     True
#          H5725400 - ELV RT EXTREME ACO 200ML ARG   200.000       ml       200        ml     True     True     True
#          H5725500 - ELV RT EXTREME ACO 400ML ARG   400.000       ml       400        ml     True     True     True
#          H5725700 - ELV RT EXTREME CTT 300ML ARG   300.000       ml       300        ml     True     True     True
#         H5725800 - ELV ACO RT5 750ml KERATIN ARG   750.000       ml       750        ml     True     True     True
#    H5726000 - ELVIVE RT5+  SH 2EN1 400ml KERATIN   400.000       ml       400        ml     True     True     True
#         H5726100 - ELV SH RT5+ 400ml KERATIN ARG   400.000       ml       400        ml     True     True     True
#        H5726200 - ELV CPP RT5+ 250ml KERATIN ARG   250.000       ml       250        ml     True     True     True
#         H5726300 - ELV SH RT5+ 200ml KERATIN ARG   200.000       ml       200        ml     True     True     True
#        H5726400 - ELV ACO RT5+ 400ml KERATIN ARG   400.000       ml       400        ml     True     True     True
#   H5726500 - ELVIVE REP TOT 5+ CTT 300ml KERATIN   300.000       ml       300        ml     True     True     True
#        H5727600 - ELV ACO RT5+ 200ml KERATIN ARG   200.000       ml       200        ml     True     True     True
#               H5480201 - FRU ALOE WATER COND 650   650.000       ml       650        ml     True     True     True
#               H5630500 - FRU ALOE WATER SH 350ml   350.000       ml       350        ml     True     True     True
#             H5630600 - FRU ALOE WATER COND 350ml   350.000       ml       350        ml     True     True     True
#             H5736900 - FRU ALOE WATER ACO 350 ml   350.000       ml       350        ml     True     True     True
#             H5737000 - FRU ALOE WATER ACO 200 ml   200.000       ml       200        ml     True     True     True
#               H5737100 - FRU ALOE WATER SH 350ml   350.000       ml       350        ml     True     True     True
#             H5737200 - FRU ALOE WATER SHP 200 ml   200.000       ml       200        ml     True     True     True
#           H5384101 - FRU GOODBYE DAÃOS SH 200ML   200.000       ml       200        ml     True     True     True
#          H5384201 - FRU GOODBYE DAÃOS ACO 200ML   200.000       ml       200        ml     True     True     True
#     H5682500 - FRU GOODBYE DAÃOS LARGO SH 350ML   350.000       ml       350        ml     True     True     True
#     H5682501 - FRU GOODBYE DAÃOS LARGO SH 350ML   350.000       ml       350        ml     True     True     True
#     H5683100 - FRU GOODBYE DAÃOS LARGO SH 200ml   200.000       ml       200        ml     True     True     True
#          H5683600 - FRU GOODBYE DAÃOS ACO 200ml   200.000       ml       200        ml     True     True     True
#          H5683601 - FRU GOODBYE DAÃOS ACO 200ml   200.000       ml       200        ml     True     True     True
#          H5684900 - FRU GOODBYE DAÃOS ACO 350ml   350.000       ml       350        ml     True     True     True
#          H5684901 - FRU GOODBYE DAÃOS ACO 350ml   350.000       ml       350        ml     True     True     True
#   C6640700 - FRU HAIR FOOD BAR SH BANAN 60GR B43    60.000        g        60        gr     True     True     True
#   C6642500 - FRU HAIR FOOD BAR SH WATER 60GR B43    60.000        g        60        gr     True     True     True
#    C6652500 - FRU HAIR FOOD BAR SH COCO 60GR B43    60.000        g        60        gr     True     True     True
#     H5473304 - FRU HAIR FOOD AGUACATE 350 ML NAT   350.000       ml       350        ml     True     True     True
#    H5717200 - FRU HAIR FOOD BANANA ACO 300ml ARG   300.000       ml       300        ml     True     True     True
#     H5717300 - FRU HAIR FOOD BANANA SH 300ml ARG   300.000       ml       300        ml     True     True     True
#   H5717400 - FRU HAIR FOOD AGUACATE SH 300ml ARG   300.000       ml       300        ml     True     True     True
#   H5717500 - FRU HAIR FOOD AGUACATE ACO300ml ARG   300.000       ml       300        ml     True     True     True
#    H5717600 - FRU HAIR FOOD COCO SH 300ml ARG CM   300.000       ml       300        ml     True     True     True
#   H5717700 - FRU HAIR FOOD COCO ACO 300ml ARG CM   300.000       ml       300        ml     True     True     True
#     H5717800 - FRU HAIR FOOD SANDIA SH 300ML ARG   300.000       ml       300        ml     True     True     True
#    H5717900 - FRU HAIR FOOD SANDIA ACO 300ml ARG   300.000       ml       300        ml     True     True     True
#   H5718100 - FRU H FOOD COCONUT JAR 350ml ARG CM   350.000       ml       350        ml     True     True     True
#     H5718300 - FRU H FOOD AGUACATE JAR 350ml ARG   350.000       ml       350        ml     True     True     True
#    H5718500 - FRU HAIR FOOD ALOE SH 300ml ARG CM   300.000       ml       300        ml     True     True     True
#   H5718800 - FRU HAIR FOOD ALOE ACO 300ml ARG CM   300.000       ml       300        ml     True     True     True
#     H5723700 - FRU HAIR FOOD CACAO JAR 350ml ARG   350.000       ml       350        ml     True     True     True
#     H5723800 - Fru Hair Food Cacao Aco 300ml ARG   300.000       ml       300        ml     True     True     True
#   H5723900 - Fru Hair Food Cacao SH 300ml ARG CM   300.000       ml       300        ml     True     True     True
#        H5682400 - FRU RIZOS MANEJABLES ACO 350ml   350.000       ml       350        ml     True     True     True
#         H5682600 - FRU RIZOS MANEJABLES SH 350ML   350.000       ml       350        ml     True     True     True
#           H5685100 - FRU RIZO MANEJABLE SH 200ML   200.000       ml       200        ml     True     True     True
#          H5685200 - FRU RIZO MANEJABLE ACO 200ML   200.000       ml       200        ml     True     True     True
#             H5735900 - FRU RIZO MANEJABLE SH 350   350.000       ml       350        ml     True     True     True
#             H5735901 - FRU RIZO MANEJABLE SH 350   350.000       ml       350        ml     True     True     True
#          H5737400 - FRU RIZO MANEJABLE ACO 200ml   200.000       ml       200        ml     True     True     True
#           H5742500 - FRU RIZO MANEJBLE ACO 350ML   350.000       ml       350        ml     True     True     True
#           H5742501 - FRU RIZO MANEJBLE ACO 350ML   350.000       ml       350        ml     True     True     True
#       H5703400 - FRU ACO HYDRA LISS 350ml ARG CM   350.000       ml       350        ml     True     True     True
#       H5703401 - FRU ACO HYDRA LISS 350ml ARG CM   350.000       ml       350        ml     True     True     True
#        H5704400 - FRU SH HYDRA LISS 350ml ARG CM   350.000       ml       350        ml     True     True     True
#        H5704401 - FRU SH HYDRA LISS 350ml ARG CM   350.000       ml       350        ml     True     True     True
#              H5717000 - FRU HYDRA LISS ACO 200ml   200.000       ml       200        ml     True     True     True
#              H5718600 - FRU SH HYDRA LISS 200 ML   200.000       ml       200        ml     True     True     True
#       H5398501 - FRU OIL R LISS COCONUT SH 650ML   650.000       ml       650        ml     True     True     True
#       H5398503 - FRU OIL R LISS COCONUT SH 650ML   650.000       ml       650        ml     True     True     True
#      H5398701 - FRU OIL R LISS COCONUT ACO 650ML   650.000       ml       650        ml     True     True     True
#         H5682700 - FRU OIL R ACO LISO COCO 350ML   350.000       ml       350        ml     True     True     True
#         H5682800 - FRU OIL R LISO COCO ACO 200ML   200.000       ml       200        ml     True     True     True
#          H5682900 - FRU OIL R SH LISO COCO 350ML   350.000       ml       350        ml     True     True     True
#         H5683000 - FRU OIL R LISO COCO SH 200 ML   200.000       ml       200        ml     True     True     True
#           H5683200 - OIL R RECARGA NUT ACO 350ml   350.000       ml       350        ml     True     True     True
#        H5683300 - FRU RECARGA NUTRI ARG SH 350ml   350.000       ml       350        ml     True     True     True
#     H5683400 - FRU OIL REP RECARGA NUT ACO 200ml   200.000       ml       200        ml     True     True     True
#        H5683500 - FRU OIL R RECARGA NUT SH 200ml   200.000       ml       200        ml     True     True     True
#   H5685500 - Fru OR Recarga Nutritiva CPP 250 ml   250.000       ml       250        ml     True     True     True
#        H5685700 - FRUCTIS OR LISO COCO CPP 250ML   250.000       ml       250        ml     True     True     True
#                H5697900 - FRU SUPER OLEO 8 100ML   100.000       ml       100        ml     True     True     True
#         H5735100 - FRU O.REPAIR LISO COCO SH 350   350.000       ml       350        ml     True     True     True
#        H5735300 - FRU O.REPAIR LISO COCO ACO 350   350.000       ml       350        ml     True     True     True
#        H5735301 - FRU O REPAIR LISO COCO ACO 350   350.000       ml       350        ml     True     True     True
#      H5736100 - FRU O.REPAIR RECARGA NUT CPP 250   250.000       ml       250        ml     True     True     True
#    H5736500 - FRU O.REPAIR RECARGA NUT ACO 200ml   200.000       ml       200        ml     True     True     True
#     H5736600 - FRU O.REPAIR RECARGA NUT ACO350ml   350.000       ml       350        ml     True     True     True
#     H5736601 - FRU O REPAIR RECARGA NUT ACO350ml   350.000       ml       350        ml     True     True     True
#     H5736700 - FRU O.REPAIR RECARGA NUT SH 350ml   350.000       ml       350        ml     True     True     True
#     H5736800 - FRU O.REPAIR RECARGA NUT SH 200ml   200.000       ml       200        ml     True     True     True
#       H5737300 - FRU O.REPAIR LISO COCO SH 200ml   200.000       ml       200        ml     True     True     True
#      H5737700 - FRU O.REPAIR LISO COCO CPP 250ml   250.000       ml       250        ml     True     True     True
#     XAR01622 - FRU OR RECARGA NUT. ACO 650ml ARG   650.000       ml       650        ml     True     True     True
#     XAR01623 - FRU OR RECARGA NUTRITIVA SH 650ml   650.000       ml       650        ml     True     True     True
#   XAR01624 - FRU OIL R LISS COCONUT ACO 650ML AR   650.000       ml       650        ml     True     True     True
#     XAR01625 - FRU OIL R LISS C.NUT SH 650ML ARG   650.000       ml       650        ml     True     True     True
#           H5748300 - Fructis Probiotics Cond 650   650.000       ml       650        ml     True     True     True
#               H5749600 - Force biotics shp 650ml   650.000       ml       650        ml     True     True     True
#                H5796900 - Fru.Probiotics shp 350   350.000       ml       350        ml     True     True     True
#              H5797600 - Fru.Probiotics shp 200ml   200.000       ml       200        ml     True     True     True
#              H5797700 - Fru.Probiotics ACO 200ml   200.000       ml       200        ml     True     True     True
#               H5797800 - Fru.Probiotics Cond 350   350.000       ml       350        ml     True     True     True
#           H5799000 - Fru.Probiotics 10 N 1 250ml   250.000       ml       250        ml     True     True     True
#             H1114202 - FRU BRILLO VITAM SH 650ML   650.000       ml       650        ml     True     True     True
#            H1117802 - FRU BRILLO VITAM ACO 650ML   650.000       ml       650        ml     True     True     True
#        H5383900 - FRU BRILLO VITAMINADO SH 200ML   200.000       ml       200        ml     True     True     True
#       H5384000 - FRU BRILLO VITAMINADO ACO 200ML   200.000       ml       200        ml     True     True     True
#             H5629600 - FRU BRILLO VITAM SH 350ml   350.000       ml       350        ml     True     True     True
#            H5629900 - FRU BRILLO VITAM ACO 350ml   350.000       ml       350        ml     True     True     True
#    H5687901 - ELV OLEO NUTR UNIV SH 400ml ARG CM   400.000       ml       400        ml     True     True     True
#               H5746300 - ELV Glyco Gloss CT 300g   300.000        g       300        gr     True     True     True
#       H5593500 - ELV HIDRA HIALURONICO ACO 400ML   400.000       ml       400        ml     True     True     True
#       H5724900 - HIDRA HIALURONICO CPP 250ML ARG   250.000       ml       250        ml     True     True     True
#       H5727000 - ELV CT KERA-LISO 230Â° 300G ARG   300.000        g       300        gr     True     True     True
#        H5727100 - ELV CPP KERA-LISO MK 250ML ARG   250.000       ml       250        ml     True     True     True
#                      H5737800 - FRU ALOE CPP 250   250.000       ml       250        ml     True     True     True
#             H5735800 - FRU RIZO MANEJABLE SH 200   200.000       ml       200        ml     True     True     True
#            H5736000 - FRU RIZO MANEJABLE CPP 250   250.000       ml       250        ml     True     True     True
#        H5735200 - FRU O.REPAIR LISO COCO ACO 200   200.000       ml       200        ml     True     True     True
#   H5681000 - ELVIVE COLOR VIVE MASK 300ml Arg CM   300.000       ml       300        ml     True     True     True
#   H5727500 - ELVIVE COLOR VIVE MASK 300ml Arg CM   300.000       ml       300        ml     True     True     True
#   H5687800 - ELVIVE OLEO REGULAR CTT 300G ARG CM   300.000        g       300        gr     True     True     True
#   H5687801 - ELVIVE OLEO REGULAR CTT 300G ARG CM   300.000        g       300        gr     True     True     True
#    H5688001 - ELV OLEO NUTR UNIV SH 200ml ARG CM   200.000       ml       200        ml     True     True     True
#            H5666400 - ELV CPP RT5+ 250ml KERATIN   250.000       ml       250        ml     True     True     True
#                 H5481600 - FRU ALOE WATER SH 200   200.000       ml       200        ml     True     True     True
#                H5481700 - FRU ALOE WATER ACO 200   200.000       ml       200        ml     True     True     True
#         H5685600 - FRU ALOE HIDRA BOMB CPP 250ML   250.000       ml       250        ml     True     True     True
#              H5685000 - FRUCTIS BDD LP CPP 250ML   250.000       ml       250        ml     True     True     True
#   H5718000 - FRU HAIR FOOD ALOE JAR 350ML ARG CM   350.000       ml       350        ml     True     True     True
#    H5718200 - FRU H FOOD BANANA JAR 350ml ARG CM   350.000       ml       350        ml     True     True     True
#    H5718400 - FRU H FOOD SANDIA JAR 350ml ARG CM   350.000       ml       350        ml     True     True     True
#          H5743400 - FRUCTIS HYDRA LISS CPP 250ML   250.000       ml       250        ml     True     True     True
#              H5664200 - ELV ARCIL EXTR ACO 750ml   750.000       ml       750        ml     True     True     True
#               H5664300 - ELV ARCIL EXTR SH 750ml   750.000       ml       750        ml     True     True     True
#    H5681100 - ELVIVE COLOR VIVE ACO 750ml Arg CM   750.000       ml       750        ml     True     True     True
#     H5681400 - ELVIVE COLOR VIVE SH 750ml Arg CM   750.000       ml       750        ml     True     True     True
#       H5551300 - ELVIVE DREAM LONG LISS SH 750ml   750.000       ml       750        ml     True     True     True
#     H5665600 - ELV O.EXTRAORD NUTR UNIV CD 750ml   750.000       ml       750        ml     True     True     True
#     H5665800 - ELV O.EXTRAORD NUTR UNIV SH 750ml   750.000       ml       750        ml     True     True     True
#               H5673800 - ELV OLEO COCO ACO 750ml   750.000       ml       750        ml     True     True     True
#              H5745000 - ELV Glyco Gloss SH 750ml   750.000       ml       750        ml     True     True     True
#             H5745100 - ELV Glyco Gloss ACO 750ml   750.000       ml       750        ml     True     True     True
#       H5593600 - ELV HIDRA HIALURONICO ACO 750ML   750.000       ml       750        ml     True     True     True
#       H5724800 - HIDRA HIALURONICO ACO 750ML ARG   750.000       ml       750        ml     True     True     True
#     H5662500 - ELV KERALISO BRIL Y SED ACO 750ml   750.000       ml       750        ml     True     True     True
#                   H0665004 - ELV SH RT5+ 200ML .   200.000       ml       200        ml     True     True     True
#              H5661700 - ELV SH RT5 750ml KERATIN   750.000       ml       750        ml     True     True     True
#              H5663400 - ELV RT EXTREME ACO 750ml   750.000       ml       750        ml     True     True     True
#               H5664800 - ELV RT EXTREME SH 750ml   750.000       ml       750        ml     True     True     True
#           H5725300 - ELV RT EXTREME SH 750ML ARG   750.000       ml       750        ml     True     True     True
#          H5725600 - ELV RT EXTREME ACO 750ML ARG   750.000       ml       750        ml     True     True     True
#          H5725900 - ELV SH RT5 750ml KERATIN ARG   750.000       ml       750        ml     True     True     True
#                 H5480001 - FRU ALOE WATER SH 650   650.000       ml       650        ml     True     True     True
#                      H5629700 - FRU GBD SH 350ml   350.000       ml       350        ml     True     True     True
#                     H5629800 - FRU GBD ACO 350ml   350.000       ml       350        ml     True     True     True
#          H5465203 - FRU HAIR FOOD COCONUT 350 ML   350.000       ml       350        ml     True     True     True
#      H5465205 - FRU HAIR FOOD COCONUT 350 ML NAT   350.000       ml       350        ml     True     True     True
#         H5473302 - FRU HAIR FOOD AGUACATE 350 ML   350.000       ml       350        ml     True     True     True
#              H5537201 - FRU HAIR FOOD ALOE 350ML   350.000       ml       350        ml     True     True     True
#          H5537204 - FRU HAIR FOOD ALOE 350ML NAT   350.000       ml       350        ml     True     True     True
#        H5639400 - FRU HAIR FOOD SANDIA JAR 350ML   350.000       ml       350        ml     True     True     True
#    H5639403 - FRU HAIR FOOD SANDIA JAR 350ML NAT   350.000       ml       350        ml     True     True     True
#     H5685800 - FRUCTIS RIZOS PODEROSOS CPP 250ML   250.000       ml       250        ml     True     True     True
#     H5640700 - FRU OR RECARGA NUTRITIVA SH 650ml   650.000       ml       650        ml     True     True     True
#    H5640900 - FRU OR RECARGA NUTRITIVA ACO 650ml   650.000       ml       650        ml     True     True     True
#    H5640902 - FRU OR RECARGA NUTRITIVA ACO 650ml   650.000       ml       650        ml     True     True     True
#         H5735101 - FRU O REPAIR LISO COCO SH 350   350.000       ml       350        ml     True     True     True
#     H5736701 - FRU O REPAIR RECARGA NUT SH 350ml   350.000       ml       350        ml     True     True     True
#            H5666501 - ELV CPP KERA-LISO MK 250ml   250.000       ml       250        ml     True     True     True
#           H5465602 - FRU HAIR FOOD BANANA 350 ML   350.000       ml       350        ml     True     True     True
#            H5666500 - ELV CPP KERA-LISO MK 250ml   250.000       ml       250        ml     True     True     True
#           H5465603 - FRU HAIR FOOD BANANA 350 ML   350.000       ml       350        ml     True     True     True
#    H5641200 - FRU OR RECARGA NUTRITIVA ACO 200ml   200.000       ml       200        ml     True     True     True
#      H5559900 - ELVIVE DREAM LONG LISS CPP 250ml   250.000       ml       250        ml     True     True     True
#   H1327606 - ELV O.EXTRAO NUTR UNIV SH400ML A.CM   400.000       ml       400        ml     True     True     True
#   H1335101 - ELV O.EXTRAORD NUTR UNIV SH 750ML .   750.000       ml       750        ml     True     True     True
#   H1335302 - ELV O.EXTRAORD NUTR UNIV CD 200ML .   200.000       ml       200        ml     True     True     True
#   H1335701 - ELV O.EXTRAORD NUTR UNIV CD 750ML .   750.000       ml       750        ml     True     True     True
#   H1581004 - ELV O.EXTRAO TODO TIPO SH200ML A.CM   200.000       ml       200        ml     True     True     True
#                 H5480000 - FRU ALOE WATER SH 650   650.000       ml       650        ml     True     True     True
#       H5465605 - FRU HAIR FOOD BANANA 350 ML NAT   350.000       ml       350        ml     True     True     True
#      H5398703 - FRU OIL R LISS COCONUT ACO 650ML   650.000       ml       650        ml     True     True     True
#     H5640702 - FRU OR RECARGA NUTRITIVA SH 650ml   650.000       ml       650        ml     True     True     True
#   H1335502 - ELV O.EXTRAORD NUTR UNIV CD 400ML .   400.000       ml       400        ml     True     True     True
#   C6679500 - FRU HAIR FOOD BAR SH AVOCADO 60GR B    60.000        g        60        gr     True     True     True
#          H5385500 - FRU RIZO MANEJABLE ACO 200ML   200.000       ml       200        ml     True     True     True
#    C6637100 - FRU HAIR FOOD BAR SH ALOE 60GR B43    60.000        g        60        gr     True     True     True
#          H5575601 - FRU HAIR FOOD ALOE ACO 300ml   300.000       ml       300        ml     True     True     True
#                   H0666805 - ELV SH RT5+ 400ML .   400.000       ml       400        ml     True     True     True
#      H5803900 - Dr.LengthSerumSleek100ml ARG2025   100.000       ml       100        ml     True     True     True
#                H5480301 - FRU ALOE WATER CPP 300   300.000       ml       300        ml     True     True     True
#         H5575301 - FRU HAIR FOOD BANANA SH 300ml   300.000       ml       300        ml     True     True     True
#           H5575501 - FRU HAIR FOOD ALOE SH 300ml   300.000       ml       300        ml     True     True     True
#           H5575701 - FRU HAIR FOOD COCO SH 300ml   300.000       ml       300        ml     True     True     True
#          H5575801 - FRU HAIR FOOD COCO ACO 300ml   300.000       ml       300        ml     True     True     True
#       H5575901 - FRU HAIR FOOD AGUACATE SH 300ml   300.000       ml       300        ml     True     True     True
#         H5639200 - FRU HAIR FOOD SANDIA SH 300ML   300.000       ml       300        ml     True     True     True
#        H5639300 - FRU HAIR FOOD SANDIA ACO 300ML   300.000       ml       300        ml     True     True     True
#    H5641300 - FRU OR RECARGA NUTRITIVA CPP 300ml   300.000       ml       300        ml     True     True     True
#      H5769400 - FRU HAIRFOOD ACO PIÃA 300ml ARG   300.000       ml       300        ml     True     True     True
#      H5769500 - FRU HAIRFOOD PIÃA JAR 350ml ARG   350.000       ml       350        ml     True     True     True
#      H5576001 - FRU HAIR FOOD AGUACATE ACO 300ml   300.000       ml       300        ml     True     True     True
#        H1831702 - FRU RIZOS MANEJABLES CPP 300ML   300.000       ml       300        ml     True     True     True
#       H5396500 - ELV EXTR OIL SUMM EDIT COND 200   200.000       ml       200        ml     True     True     True
#         H0878802 - ELV OLEO EXTRAORDINARIO 100ML   100.000       ml       100        ml     True     True     True
#        H5575401 - FRU HAIR FOOD BANANA ACO 300ml   300.000       ml       300        ml     True     True     True
#               H5000500 - ELV ARCIL EXTR SH 750ML   750.000       ml       750        ml     True     True     True
#              H1336703 - ELV OLEO COCO ACO 400 ML   400.000       ml       400        ml     True     True     True
#              H1499101 - ELV FIBRALOGY SH 400ML .   400.000       ml       400        ml     True     True     True
#            H1301601 - ELV RT EXTREME ACO 750ML .   750.000       ml       750        ml     True     True     True
#              H5537202 - FRU HAIR FOOD ALOE 350ML   350.000       ml       350        ml     True     True     True
#        H5575400 - FRU HAIR FOOD BANANA ACO 300ml   300.000       ml       300        ml     True     True     True
#      H5576000 - FRU HAIR FOOD AGUACATE ACO 300ml   300.000       ml       300        ml     True     True     True
#   H0590205 - FRU AMARILLO OIL REPAIR 3A ACO 650M   650.000       ml      None      None    False    False    False
#                H1008004 - FRU SUPER OLEO 8 100ML   100.000       ml       100        ml     True     True     True
#   H0938502 - ELV KERALISO BRIL Y SED ACO 200ML .   200.000       ml       200        ml     True     True     True
#                H1336302 - ELV OLEO COCO SH 750ML   750.000       ml       750        ml     True     True     True
#               H5480101 - FRU ALOE WATER COND 350   350.000       ml       350        ml     True     True     True
#                      H1386304 - FRU GBD SH 350ML   350.000       ml       350        ml     True     True     True
#         H5575300 - FRU HAIR FOOD BANANA SH 300ml   300.000       ml       300        ml     True     True     True
#             H5511800 - ELV DREAM LENGTH SH 200ML   200.000       ml       200        ml     True     True     True
#         H0878801 - ELV OLEO EXTRAORDINARIO 100ML   100.000       ml       100        ml     True     True     True
#               H5384700 - FRU OIL REPAIR SH 200ML   200.000       ml       200        ml     True     True     True
#              H5384800 - FRU OIL REPAIR ACO 200ML   200.000       ml       200        ml     True     True     True
#             H5457200 - FRU OR LISO COCO SH 200ML   200.000       ml       200        ml     True     True     True
#   H1336500 - ELV O.EXTRAORD NUTR PROF CD 200ML .   200.000       ml       200        ml     True     True     True
#             H5500800 - ELV DREAM LENGTH SH 200ML   200.000       ml       200        ml     True     True     True
#            H5501300 - ELV DREAM LENGTH CPP 250ML   250.000       ml       250        ml     True     True     True
#                H5480300 - FRU ALOE WATER CPP 300   300.000       ml       300        ml     True     True     True
#           H5511900 - ELV DREAM LENGTH COND 200ML   200.000       ml       200        ml     True     True     True
#         H5398801 - FRU OIL REP COCONUT CPP 300ML   300.000       ml       300        ml     True     True     True
#   H0590404 - FRU AMARILLO OIL REPAIR SH 650ML RE   650.000       ml       650        ml     True     True     True
#                    3D MEGA QUESO PC DTS 25GRX120    25.000        g        25        gr     True     True     True
#                               3D QUESO 143GX18X1   143.000        g       143        gr     True     True     True
#                                 3D QUESO 165GX20   165.000        g       165        gr     True     True     True
#                        3D QUESO 165GX20 PROMO PI   165.000        g       165        gr     True     True     True
#                                3D QUESO 43GX75X1    43.000        g        43        gr     True     True     True
#                                3D QUESO 85GX27X1    85.000        g        85        gr     True     True     True
#                                3D QUESO 92GX27X1    92.000        g        92        gr     True     True     True
#                               3DMEGAQUESO100GX24   100.000        g       100        gr     True     True     True
#                               3DMEGAQUESO150GX17   150.000        g       150        gr     True     True     True
#                               3DMEGAQUESO151GX17   151.000        g       151        gr     True     True     True
#                               3DMEGAQUESO23GX120    23.000        g        23        gr     True     True     True
#                                3DMEGAQUESO46GX60    46.000        g        46        gr     True     True     True
#                                3DMEGAQUESO47GX60    47.000        g        47        gr     True     True     True
#                                3DMEGAQUESO95GX24    95.000        g        95        gr     True     True     True
#                        3DS MEGA QUESO 105GR X 24   105.000        g       105        gr     True     True     True
#                        3DS MEGA QUESO 48GRX60 PI    48.000        g        48        gr     True     True     True
#                                 CHEETOS 150GRX17   150.000        g       150        gr     True     True     True
#                                 CHEETOS 151GRX17   151.000        g       151        gr     True     True     True
#                                  CHEETOS 151GX18   151.000        g       151        gr     True     True     True
#                                 CHEETOS 238GRX12   238.000        g       238        gr     True     True     True
#                                 CHEETOS 23GRX108    23.000        g        23        gr     True     True     True
#                                 CHEETOS 250GRX12   250.000        g       250        gr     True     True     True
#                                  CHEETOS 47GRX66    47.000        g        47        gr     True     True     True
#                                  CHEETOS 48GRX66    48.000        g        48        gr     True     True     True
#                                  CHEETOS 94GRX24    94.000        g        94        gr     True     True     True
#                                  CHEETOS 95GRX24    95.000        g        95        gr     True     True     True
#                         CHEETOS QUESO 105GR X 24   105.000        g       105        gr     True     True     True
#                      CHEETOS QUESO 105GR X 24 PI   105.000        g       105        gr     True     True     True
#                          CHEETOS QUESO 140GX18X1   140.000        g       140        gr     True     True     True
#                         CHEETOS QUESO 165GX17 PI   165.000        g       165        gr     True     True     True
#                          CHEETOS QUESO 229GX12X1   229.000        g       229        gr     True     True     True
#                           CHEETOS QUESO 43GX70X1    43.000        g        43        gr     True     True     True
#                           CHEETOS QUESO 85GX24X1    85.000        g        85        gr     True     True     True
#                       CHEETOS QUESO CREMA 43GX66    43.000        g        43        gr     True     True     True
#                       CHEETOS QUESO CREMA 85GX24    85.000        g        85        gr     True     True     True
#                    DORITOS DINAMITA FH 33GX110X1    33.000        g        33        gr     True     True     True
#               DORITOS DINAMITA FH 33GX40X1 EX AR    33.000        g        33        gr     True     True     True
#                    DORITOS DINAMITA FH 45GX110X1    45.000        g        45        gr     True     True     True
#                     DORITOS DINAMITA FH 70GX44X1    70.000        g        70        gr     True     True     True
#              DORITOS DINAMITA FH 70GX64X1 EX ARG    70.000        g        70        gr     True     True     True
#                     DORITOS DINAMITA FH 82GX38X1    82.000        g        82        gr     True     True     True
#                    DORITOS QUESO 129GX17 EXP ARG   129.000        g       129        gr     True     True     True
#                            DORITOS QUESO 129GX19   129.000        g       129        gr     True     True     True
#                           DORITOS QUESO 135GRX18   135.000        g       135        gr     True     True     True
#                           DORITOS QUESO 140GRX15   140.000        g       140        gr     True     True     True
#                           DORITOS QUESO 140GRX18   140.000        g       140        gr     True     True     True
#                    DORITOS QUESO 140GX14 EXP ARG   140.000        g       140        gr     True     True     True
#                            DORITOS QUESO 140GX19   140.000        g       140        gr     True     True     True
#                            DORITOS QUESO 150GX18   150.000        g       150        gr     True     True     True
#                         DORITOS QUESO 150GX18 PI   150.000        g       150        gr     True     True     True
#                            DORITOS QUESO 200GX14   200.000        g       200        gr     True     True     True
#                           DORITOS QUESO 20GX88X1    20.000        g        20        gr     True     True     True
#                           DORITOS QUESO 220GRX13   220.000        g       220        gr     True     True     True
#                            DORITOS QUESO 220GX14   220.000        g       220        gr     True     True     True
#                           DORITOS QUESO 230GRX13   230.000        g       230        gr     True     True     True
#                            DORITOS QUESO 250GX12   250.000        g       250        gr     True     True     True
#                   DORITOS QUESO 40GX58X1 EXP ARG    40.000        g        40        gr     True     True     True
#                           DORITOS QUESO 40GX70X1    40.000        g        40        gr     True     True     True
#                            DORITOS QUESO 45GRX70    45.000        g        45        gr     True     True     True
#                     DORITOS QUESO 45GX58 EXP ARG    45.000        g        45        gr     True     True     True
#                         DORITOS QUESO 46GRX70 PI    46.000        g        46        gr     True     True     True
# ...
#                           Ã‡Ä°ZÄ°Â KR.Â 4x68Gx12    68.000        g        68        gr     True     True     True
#                                         KGJ 500G   500.000        g       500        gr     True     True     True
#                    PROBÄ°S ATIÅžTIRMALIK 3X75GX8    75.000        g        75        gr     True     True     True
#               Ã‡OKOMEL MARS. Ã‡Ä°LEKLÄ° 3x12Gx30    12.000        g        12        gr     True     True     True
#       MCV DIGESTIVE THINS SÃœT.Ã‡Ä°K.BÄ°S.93Gx16    93.000        g        93        gr     True     True     True
#         ÃœLK SIMIT KRAKER 41GX12 KOLÄ°LÄ° SATIÅž    41.000        g        41        gr     True     True     True
#       Ã‡Ä°ZÄ° KRA. HAÅžHAÅžLI & BAHARATLI 70GX24    70.000        g        70        gr     True     True     True
#             SAKLIKÃ–Y FIN.KREMALI BÄ°S.3X100GX12   100.000        g       100        gr     True     True     True
#                                 Kiri Blocks 200G   200.000        g       200        gr     True     True     True
#                        ULK Ã‡UBUK KR.SADE 40Gx36    40.000        g        40        gr     True     True     True
#                                    Burger 2x200G   200.000        g       200        gr     True     True     True
#           BÄ°SKREM KLASÄ°K PILEPACK 40Gx36 Ã–ZEL    40.000        g        40        gr     True     True     True
#                         Kiri Cooking Cream 1000G  1000.000        g      1000        gr     True     True     True
#                     ULK BADEM KRAKER SADE 38GX20    38.000        g        38        gr     True     True     True
#                                         KGJ 900G   900.000        g       900        gr     True     True     True
#               Ã‡Ä°ZÄ°VÄ°Ã‡Â PEY.SAND.KR.Â 82Gx24    82.000        g        82        gr     True     True     True
#                  SAKLIKÃ–Y FIN.KRE.BÄ°SK.113Gx24   113.000        g       113        gr     True     True     True
#                                Kiri Blocks 1000G  1000.000        g      1000        gr     True     True     True
#                                      Spread 500G   500.000        g       500        gr     True     True     True
#    Ã‡Ä°ZÄ° Ã‡ITIR TULUM PEYN&KÃ–Z BÄ°BER 120GX14   120.000        g       120        gr     True     True     True
#                      BÄ°SKREM B.BOY RULO 150Gx18   150.000        g       150        gr     True     True     True
#                   RONDO MUZLU KRE.BÄ°SK.68,4Gx24    68.400        g      68.4        gr     True     True     True
#            ULK BADEM KRAKER TACO AROMALI 135Gx14   135.000        g       135        gr     True     True     True
#                             HAYLAYF BÄ°SK.64Gx24    64.000        g        64        gr     True     True     True
#                           COCA COLA ZERO 330MLX1   330.000       ml       330        ml     True     True     True
#            BÄ°SKREM KAK.KRE.B.BOY POÅžET 190Gx15   190.000        g       190        gr     True     True     True
#                         ULK.SUS.Ã‡UBUK KR.70GX22    70.000        g        70        gr     True     True     True
#                 SAKLIKÃ–Y KLASÄ°K BÄ°SK.3X131GX9   131.000        g       131        gr     True     True     True
#                      ULK KRE.RONDO MUZLU 8X61GX6    61.000        g        61        gr     True     True     True
#       ALTINBAÅžAK TAHIL CÄ°PS 50G FAB. STAND KOL    50.000        g        50        gr     True     True     True
#                    STARS COOKIE COCOSTAR 47GX6X4    47.000        g        47        gr     True     True     True
#                                         Yum 200G   200.000        g       200        gr     True     True     True
#                    HANIMELLER Ã‡OKODAMLA 6X82GX8    82.000        g        82        gr     True     True     True
#                                Ã‡OKOPRENS 30Gx48    30.000        g        30        gr     True     True     True
#                                         KGJ 240G   240.000        g       240        gr     True     True     True
#                 ULK PÃ–TÄ°BÃ–R BÄ°SK.KAK.450Gx10   450.000        g       450        gr     True     True     True
#                  MONSTER ULTRA WHITE CAN 500MLX1   500.000       ml       500        ml     True     True     True
#                                  Mbby 100G Light   100.000        g       100        gr     True     True     True
#                 CANPARE Ã‡Ä°K.KRE.BÄ°SK.3x81Gx12    81.000        g        81        gr     True     True     True
#                        ULK SADE Ã‡UBUK KR.80Gx20    80.000        g        80        gr     True     True     True
#       ULK PÃ–TÄ°BÃ–R BÄ°SK.Ã‡Ä°FTE KAV. 4X200GX6   200.000        g       200        gr     True     True     True
#                      MCV TOZ BÄ°SKÃœVÄ° 1000GX10  1000.000        g      1000        gr     True     True     True
#                   Ã‡OKOMEL MARS.Ã‡Ä°LEK 4x12Gx30    12.000        g        12        gr     True     True     True
#        ULK KRE.SAND.BÄ°SK.Ã‡.LEZZET FRAM.165Gx12   165.000        g       165        gr     True     True     True
#                   CANPARE Ã‡Ä°K.KRE.BÄ°SK.81Gx24    81.000        g        81        gr     True     True     True
#                           KAT KAT TAT FIN.25Gx24    25.000        g        25        gr     True     True     True
#                  ULK KRE.BÄ°SK.Ã‡Ä°LEKLÄ° 61GX24    61.000        g        61        gr     True     True     True
#       KAT KAT TAT CEV.EV BAK.TAD.MÄ°LFÃ–Y 28Gx24    28.000        g        28        gr     True     True     True
#                           ULK BEBE BÄ°SK.190Gx12   190.000        g       190        gr     True     True     True
#              HANIMELLER FIN.RULO 3LÃœ MP 3x82Gx8    82.000        g      3000        ml    False    False    False
#           TAÃ‡ KRAKER SUSAMLI Ã‡Ã–REKOTLU 76GX18    76.000        g        76        gr     True     True     True
#         SAKLIKÃ–Y YLF & Ä°NCÄ°RLÄ° BÄ°SK.122GX24   122.000        g       122        gr     True     True     True
#                            ULK FÄ°NGER 3x150Gx10   150.000        g       150        gr     True     True     True
#                       ULK KRE.SAND.BÄ°SK.8X61GX8    61.000        g        61        gr     True     True     True
#        MCV DIGESTIVE BÄ°T.Ã‡Ä°K.KAP.102Gx16 FLOW   102.000        g       102        gr     True     True     True
#             HANIMELLER LÄ°MONLU KURABÄ°YE 276GX9   276.000        g       276        gr     True     True     True
#                                ROYAL BLISS 200ML   200.000       ml       200        ml     True     True     True
#                     HANIMELLER COKODAMLA 3x82Gx8    82.000        g        82        gr     True     True     True
#                        ULK FÄ°NGER BÄ°SK.117GX28   117.000        g       117        gr     True     True     True
#      SAKLIKÃ–Y LÄ°MON KRE.CHEESECAK.BÄ°S.100GX18   100.000        g       100        gr     True     True     True
#               ULK KREMALI KAKAOLU BÄ°SK.4X61GX11    61.000        g        61        gr     True     True     True
#                  ULK KRE.SAN.BÄ°SK.SADE 4x61Gx11    61.000        g        61        gr     True     True     True
#                                        Jars 900G   900.000        g       900        gr     True     True     True
#                              COCA COLA ZERO 1LX4  1000.000       ml      1000        ml     True     True     True
#                             ULK Ã‡UBUK KR.74GX20    74.000        g        74        gr     True     True     True
#         JACOBS MINI CHEDDARS STICKS STEAK 92Gx14    92.000        g        92        gr     True     True     True
#              KRÄ°SPÄ° TIRTIKLI KR.KETÃ‡AP 48Gx20    48.000        g        48        gr     True     True     True
#               Ä°KRAM KRE.BÄ°SK.Ã‡Ä°K.84GX24 EU24    84.000        g        84        gr     True     True     True
#            CENTRUM WITH LUTEIN 1042 TABLETS 1X30    30.000    units      1042       XXX    False    False    False
#                    KRÄ°SPÄ° Ã‡IT.KR.ACILI 72Gx18    72.000        g        72        gr     True     True     True
#                  ULK KRE.SADE AVANT.PAKET 95Gx24    95.000        g        95        gr     True     True     True
#                      ULK KRE.BÄ°SK.MUZLU 61GRX24    61.000        g        61        gr     True     True     True
#                              TAÃ‡ KRAKER 3X76GX9    76.000        g        76        gr     True     True     True
#                                   TAÃ‡ KR.76Gx24    76.000        g        76        gr     True     True     True
#                     KRÄ°SPÄ° TIR.KR.BAHR.48GRx20    48.000        g        48        gr     True     True     True
#   Ã‡Ä°ZÄ° Ã‡ITIR TULUM PEY&KÃ–Z BÄ°.120GX14 EU24   120.000        g       120        gr     True     True     True
#                             COCA COLA ZERO 1.75L  1750.000       ml      1750        ml     True     True     True
#                                      Labneh 200G   200.000        g       200        gr     True     True     True
#             Ã‡Ä°ZÄ° Ã‡ITIR PEYNÄ°R&SOÄžAN 80Gx14    80.000        g        80        gr     True     True     True
#                         BÄ°SKREM COOKÄ°E 3x80Gx8    80.000        g        80        gr     True     True     True
#                          ULK BEBE BÄ°SK.4x250Gx4   250.000        g       250        gr     True     True     True
#           ALTINBAÅžAK Ã‡.OTLU KÄ°NOA KR.5X40GX18    40.000        g        40        gr     True     True     True
#         HANIMELLER D.OTLU TUZLU KURABÄ°YE 81GX18    81.000        g        81        gr     True     True     True
#             MCV DIGESTIVE MILK CHOC.BÄ°SK.91Gx15    91.000        g        91        gr     True     True     True
#       KRÄ°SPÄ° KETÃ‡AP MAYONEZ Ã‡UBUK KRA.40GX15    40.000        g        40        gr     True     True     True
#      MCV DIG.BEYAZ Ã‡Ä°K.&KARADUT BÄ°SK. 84,5GX1    84.500        g      84.5        gr     True     True     True
#                         Ã‡OKOMEL DEV SADE 22GX36    22.000        g        22        gr     True     True     True
#              Ã‡OKOMEL MARSH. Ã‡Ä°LEKLÄ° 15X12GX6    12.000        g        12        gr     True     True     True
#        HANIMELLER ALAÃ‡ATI KURAB.ROLLPACK 81Gx18    81.000        g        81        gr     True     True     True
#                                  FANTA ZERO 1.5L  1500.000       ml      1500        ml     True     True     True
#       SAKLIKÃ–Y KAVILCA UNLU Ã‡Ä°K.KREM.78,5GX18    78.500        g      78.5        gr     True     True     True
#                 SAKLIKÃ–Y SÃœT.KRE.BÄ°SK.125Gx12   125.000        g       125        gr     True     True     True
#                                      Spread 350G   350.000        g       350        gr     True     True     True
#                                          Cd 140G   140.000        g       140        gr     True     True     True
#                  HANIMELLER Ã‡.DAMLA RULO 82Gx18    82.000        g        82        gr     True     True     True
#             HANIMELLER ASORTÄ° PÅžT NOST 150Gx12   150.000        g       150        gr     True     True     True
#                    KRÄ°SPÄ° TIR.KR.ACILI 92GRX14    92.000        g        92        gr     True     True     True
#                    Ä°KRAM KRE.BÄ°SK.Ã‡Ä°K.84Gx24    84.000        g        84        gr     True     True     True
#                        Ã‡OKOPRENS STD.KL.300Gx48   300.000        g       300        gr     True     True     True
#                                          Cd 280G   280.000        g       280        gr     True     True     True
#                  PROBÄ°S ATIÅž.SAND.BÄ°SK.75Gx18    75.000        g        75        gr     True     True     True
#                     ULK PÃ–TÄ°BÃ–R BÄ°SK.175Gx16   175.000        g       175        gr     True     True     True
#                       ULK FÄ°NGER BÄ°SK.5x150Gx5   150.000        g       150        gr     True     True     True
#                     KRÄ°SPÄ° TIR.KRA.BAHR.92Gx14    92.000        g        92        gr     True     True     True
#    Ã‡OKOMEL POFTÄ° Ã‡Ä°LEK AR.MARSH.BÄ°S.18GRx48    18.000        g        18        gr     True     True     True
#                   ULK FINGER BÄ°SK.NOS.5x150Gx10   150.000        g       150        gr     True     True     True
#                       ULK KRE.SAND.BÄ°SK.8x69Gx8    69.000        g        69        gr     True     True     True
#             HANIMELLER LÄ°MONLU KURABÄ°YE 138Gx9   138.000        g       138        gr     True     True     True
#                    KRÄ°SPÄ° TIR.KR.ACILI 48GRX20    48.000        g        48        gr     True     True     True
#              BISKREM EXTRA 184Gx12x6 STAND KOLÄ°   184.000        g       184        gr     True     True     True
#            MCV DIGESTIVE ORIGINAL 120Gx15 F.PACK   120.000        g       120        gr     True     True     True
#                       KAT KAT TAT Ã‡Ä°LEK 28Gx24    28.000        g        28        gr     True     True     True
#                           ULK BEBE BÄ°SK.172Gx12   172.000        g       172        gr     True     True     True
#                             HAYLAYF BÄ°SK.75Gx24    75.000        g        75        gr     True     True     True
#              HANIMELLER FRAMBUAZ SOSLU 3X94,5GX8    94.500        g      94.5        gr     True     True     True
#                                  COCA COLA 1.75L  1750.000       ml      1750        ml     True     True     True
#       SAKLIKÃ–Y FRAM.KRE.CHEESECAKE BÄ°S.100GX18   100.000        g       100        gr     True     True     True
#                   BÄ°SKREM EXTRA KAK.KRE.230Gx12   230.000        g       230        gr     True     True     True
#                  KRÄ°SPÄ° ACILI Ã‡UBUK KR.43Gx15    43.000        g        43        gr     True     True     True
#    Ã‡Ä°ZÄ° Ã‡ITIR TULUM PEYN.&KÃ–Z BÄ°BER 40GX20    40.000        g        40        gr     True     True     True
#        ULK KRE.SAND.BÄ°S.Ã‡.LEZZ.MINI KAK.84GX18    84.000        g        84        gr     True     True     True
#             DORE SÃœTLÃœ Ã‡Ä°K.KRE.BÄ°SK.3X86GX8    86.000        g        86        gr     True     True     True
#                      SAKLIKÃ–Y SÃœT.KRE.4X100GX9   100.000        g       100        gr     True     True     True
#                           COCA COLA ZERO 330MLX6   330.000       ml       330        ml     True     True     True
#                 BÄ°SKREM KLASÄ°K PILEPACK 40GX20    40.000        g        40        gr     True     True     True
#            KRÄ°SPÄ° TIRTIKLI KR.PEYN&SOÄž.48Gx20    48.000        g        48        gr     True     True     True
#                    ULK BADEM KRA.MISIRLI 135Gx14   135.000        g       135        gr     True     True     True
#                    ULK KRE.SAN.BÄ°SK.SADE 61GX24    61.000        g        61        gr     True     True     True
#                      PROBÄ°S MÄ°DÄ° 7LÄ° 101Gx18   101.000        g      7000        ml    False    False    False
#                                     Spread 1500G  1500.000        g      1500        gr     True     True     True
#             DORE SADE KRE.DOL.Ã‡Ä°K.BÄ°SK.79Gx24    79.000        g        79        gr     True     True     True
#             MCV DIGESTIVE DARK CHOC.BÄ°SK.91Gx15    91.000        g        91        gr     True     True     True
#      KRÄ°SPÄ° TACO&NACHO Ã‡UBUK KRA.80GX20 KARMA    80.000        g        80        gr     True     True     True
#                  Ã‡Ä°ZÄ°VÄ°Ã‡ PEY.SAND.KR.90Gx24    90.000        g        90        gr     True     True     True
#   Ã‡Ä°ZÄ°VÄ°Ã‡ Z.YAÄžLI VE KEKÄ°KLÄ° SAND.82Gx24    82.000        g        82        gr     True     True     True
#                          ULK BEBE BÄ°SK.4x200Gx4   200.000        g       200        gr     True     True     True
#                ULK BEBE BÄ°SK.172Gx12 BÄ°M KOLÄ°   172.000        g       172        gr     True     True     True
#                     Ä°KRAM KRE.BÄ°SK.FIN.6X84GX6    84.000        g        84        gr     True     True     True
#                  KRÄ°SPÄ° ACILI Ã‡UBUK KR.54Gx15    54.000        g        54        gr     True     True     True
